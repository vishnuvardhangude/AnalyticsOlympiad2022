# %%
import pandas as pd
import math
from sklearn import preprocessing
import numpy as np
from sklearn.metrics import log_loss

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = "/home/vishnu/ML/challenges/insurance/data/"

train_data_path = data_path+"train.csv"
test_data_path = data_path+"test.csv"

# %%
import pandas as pd

train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)

# %%
train_data.head()
# Out:
#        ID    AGE  GENDER DRIVING_EXPERIENCE    EDUCATION         INCOME  \
# 0  816393  40-64  female             20-29y   university   middle class
# 1  251762  26-39    male             20-29y  high school   middle class
# 2  481952  40-64    male             20-29y         none   middle class
# 3    3506  40-64    male             20-29y  high school    upper class
# 4  498013  40-64  female             20-29y         none  working class
#
#    CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  CHILDREN  \
# 0      0.638050                0.0   after 2015      0.0       0.0
# 1      0.475741                1.0  before 2015      1.0       0.0
# 2      0.839817                1.0  before 2015      1.0       1.0
# 3      0.682527                1.0  before 2015      0.0       1.0
# 4      0.572184                1.0   after 2015      1.0       1.0
#
#    POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS  \
# ...

# %%
train_data['TYPE_OF_VEHICLE'].value_counts()
# Out:
# Sports Car    34592
# Sedan         28120
# HatchBack     24900
# SUV           17388
# Name: TYPE_OF_VEHICLE, dtype: int64

# %%
test_data['TYPE_OF_VEHICLE'].value_counts()
# Out:
# Sports Car    14811
# Sedan         11968
# HatchBack     10720
# SUV            7501
# Name: TYPE_OF_VEHICLE, dtype: int64

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

for col in train_data.columns:
  # print(col)
  if(col not in ('ID')):
    print(col, train_data[col].dtypes)
    if(train_data[col].dtypes=='object'):
      le.fit(list(train_data[col]))
      train_data[col] = le.transform(list(train_data[col]))
# Out:
# AGE object
# GENDER object
# DRIVING_EXPERIENCE object
# EDUCATION object
# INCOME object
# CREDIT_SCORE float64
# VEHICLE_OWNERSHIP float64
# VEHICLE_YEAR object
# MARRIED float64
# CHILDREN float64
# POSTAL_CODE int64
# ANNUAL_MILEAGE float64
# SPEEDING_VIOLATIONS int64
# DUIS int64
# PAST_ACCIDENTS int64
# OUTCOME float64
# TYPE_OF_VEHICLE object

# %%
test_data.head()
# Out:
#        ID    AGE  GENDER DRIVING_EXPERIENCE    EDUCATION         INCOME  \
# 0  352928  40-64    male             10-19y         none  working class
# 1   38579  26-39  female             20-29y  high school    upper class
# 2  504022  40-64    male             10-19y         none    upper class
# 3  202404  26-39    male             20-29y  high school    upper class
# 4  527913    65+    male             10-19y         none   middle class
#
#    CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  CHILDREN  \
# 0      0.814707                1.0   after 2015      0.0       1.0
# 1      0.344051                1.0  before 2015      0.0       0.0
# 2      0.620691                0.0   after 2015      1.0       0.0
# 3      0.689658                1.0   after 2015      1.0       1.0
# 4      0.755666                0.0   after 2015      0.0       1.0
#
#    POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS  \
# ...

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

for col in test_data.columns:
  # print(col)
  if(col not in ('ID')):
    print(col, test_data[col].dtypes)
    if(test_data[col].dtypes=='object'):
      le.fit(list(test_data[col]))
      test_data[col] = le.transform(list(test_data[col]))
# Out:
# AGE object
# GENDER object
# DRIVING_EXPERIENCE object
# EDUCATION object
# INCOME object
# CREDIT_SCORE float64
# VEHICLE_OWNERSHIP float64
# VEHICLE_YEAR object
# MARRIED float64
# CHILDREN float64
# POSTAL_CODE int64
# ANNUAL_MILEAGE float64
# SPEEDING_VIOLATIONS int64
# DUIS int64
# PAST_ACCIDENTS int64
# TYPE_OF_VEHICLE object

# %%
train_data.dtypes
# Out:
# ID                       int64
# AGE                      int64
# GENDER                   int64
# DRIVING_EXPERIENCE       int64
# EDUCATION                int64
# INCOME                   int64
# CREDIT_SCORE           float64
# VEHICLE_OWNERSHIP      float64
# VEHICLE_YEAR             int64
# MARRIED                float64
# CHILDREN               float64
# POSTAL_CODE              int64
# ANNUAL_MILEAGE         float64
# SPEEDING_VIOLATIONS      int64
# DUIS                     int64
# PAST_ACCIDENTS           int64
# OUTCOME                float64
# TYPE_OF_VEHICLE          int64
# dtype: object

# %%
del train_data['ID']
del test_data['ID']

# %%
test_data.head()
# Out:
#    AGE  GENDER  DRIVING_EXPERIENCE  EDUCATION  INCOME  CREDIT_SCORE  \
# 0    2       1                   1          1       3      0.814707
# 1    1       0                   2          0       2      0.344051
# 2    2       1                   1          1       2      0.620691
# 3    1       1                   2          0       2      0.689658
# 4    3       1                   1          1       0      0.755666
#
#    VEHICLE_OWNERSHIP  VEHICLE_YEAR  MARRIED  CHILDREN  POSTAL_CODE  \
# 0                1.0             0      0.0       1.0        10238
# 1                1.0             1      0.0       0.0        34073
# 2                0.0             0      1.0       0.0        10238
# 3                1.0             0      1.0       1.0        10238
# 4                0.0             0      0.0       1.0        92101
#
#    ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS  TYPE_OF_VEHICLE
# ...

# %%
train_data.head()
# Out:
#    AGE  GENDER  DRIVING_EXPERIENCE  EDUCATION  INCOME  CREDIT_SCORE  \
# 0    2       0                   2          2       0      0.638050
# 1    1       1                   2          0       0      0.475741
# 2    2       1                   2          1       0      0.839817
# 3    2       1                   2          0       2      0.682527
# 4    2       0                   2          1       3      0.572184
#
#    VEHICLE_OWNERSHIP  VEHICLE_YEAR  MARRIED  CHILDREN  POSTAL_CODE  \
# 0                0.0             0      0.0       0.0        37379
# 1                1.0             1      1.0       0.0        10238
# 2                1.0             1      1.0       1.0        10238
# 3                1.0             1      0.0       1.0        92099
# 4                1.0             0      1.0       1.0        32122
#
#    ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS  OUTCOME  \
# 0         11000.0                    0     0               0      0.0
# ...

# %%
from sklearn.model_selection import train_test_split

target = train_data.OUTCOME
del train_data['OUTCOME']
X = train_data.values
y = target.values

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.30, random_state=42)
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.01, random_state=42)

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train,y_train)

# Get the mean absolute error on the validation data
y_pred = model.predict(X_val)

ll = log_loss(y_val, y_pred)

print('Random forest validation Log Loss = ', ll)
# Out:
# Random forest validation Log Loss =  15.58639767091402

# %%
y_pred
# Out:
# array([0., 1., 0., ..., 0., 0., 0.])

# %% [markdown]
# ### XGBClasifier

# %%
# !pip install xgboost==1.5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 MB 3.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
import sklearn
from sklearn import metrics

sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'matthews_corrcoef',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_absolute_percentage_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'rand_score',
#  'recall',
#  'recall_macro',
#  'recall_micro',
# ...

# %%
import xgboost
from xgboost import XGBClassifier
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import log_loss, make_scorer
from sklearn.model_selection import GridSearchCV



# {'colsample_bytree': 0.4, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# -0.6808787654577193

# {'colsample_bytree': 0.4, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300}
# -0.6810951482335726


# {'colsample_bytree': 0.6, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 150}
# -0.6809878120475077

# {'colsample_bytree': 0.5, 'gamma': 0.05, 'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 200}
# -0.6808674865852635


parameters = {'n_estimators':[100, 300, 150, 200],
              'max_depth':[3, 2],
              'gamma': [0.1, 0.5, 0.05],
              'colsample_bytree': [0.4, 0.6, 0.5],
              'learning_rate': [0.01, 0.05]
              
              }



LogLoss = make_scorer(log_loss, greater_is_better=False, needs_proba=True)

# parameters = {'n_estimators':[200],
#               'max_depth':[2, 3, 4, 5, 6],
#               'gamma': [0.1],
#               'colsample_bytree': [0.5, 0.9],
#               'learning_rate': [0.01, 0.05, 0.1],
#               'objective':['neg_log_loss']
#               }

XGBModel = XGBClassifier(use_label_encoder=False)
  
xgbmodel = GridSearchCV(XGBModel, param_grid=parameters, scoring='neg_log_loss', cv = 8, verbose=20)
# XGBModel.fit(train_X,train_y , verbose=False)

# eval_set = [(X_val, y_val)]
# model.fit(X_train, y_train, eval_metric="error", eval_set=eval_set, verbose=True)

xgbmodel.fit(X_train,y_train, verbose=True)
# sorted(xgbmodel.cv_results_.keys())


# GridSearchCV(cv=8,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      enable_categorical=False, gamma=None,
#                                      gpu_id=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,...
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=None, tree_method=None,
#                                      use_label_encoder=False,
#                                      validate_parameters=None, verbosity=None),
#              param_grid={'colsample_bytree': [0.4, 0.6, 0.8],
#                          'gamma': [0.1, 0.5, 1],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 5, 6], 'n_estimators': [150]},
#              scoring='neg_log_loss', verbose=20)
# Out:
# Fitting 8 folds for each of 144 candidates, totalling 1152 fits
# [CV 1/8; 1/144] START colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100
# [19:27:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/8; 1/144] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100;, score=-0.682 total time=   1.5s
# [CV 2/8; 1/144] START colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100
# [19:27:40] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
# 'colsample_bytree': 0.5, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200, 'objective': 'reg:squarederror'}
# -0.20248970084549828

# %%
print(xgbmodel.best_params_)

print(xgbmodel.best_score_)


# {'colsample_bytree': 0.4, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# -0.6808787654577193

# {'colsample_bytree': 0.4, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300}
# -0.6810951482335726


# {'colsample_bytree': 0.6, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 150}
# -0.6809878120475077

# {'colsample_bytree': 0.5, 'gamma': 0.05, 'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 200}
# -0.6808674865852635

# {'colsample_bytree': 0.6, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
# -0.6807487156888641
# Out:
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
# -0.6807487156888641

# %% [markdown]
# ### XGB train

# %%
# XGBClassifier(learning_rate=0.05,  n_estimators=200, max_depth=3, colsample_bytree = 0.5, gamma= 0.1, objective='binary:logistic', use_label_encoder=False)
# XGBoost validation Log loss =  0.6819472321905787
# submission score 0.68048

#XGBClassifier(learning_rate=0.007,  n_estimators=300, max_depth=6, colsample_bytree = 0.8, gamma= 0.1, objective='binary:logistic', use_label_encoder=False)
#XGBoost validation Log loss =  0.6819613814931067

# %%
import xgboost
from xgboost import XGBClassifier

# xgb=XGBClassifier(n_estimators=300, max_depth=6, colsample_bytree=0.8, reg_lambda=10, learning_rate=0.007)

{'colsample_bytree': 0.6, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}

XGBModel = XGBClassifier(learning_rate=0.05, n_estimators=100, max_depth=2, colsample_bytree = 0.6, gamma= 0.1
                         , use_label_encoder=False)
  
  
# XGBModel.fit(train_X,train_y , verbose=False)

# eval_set = [(X_val, y_val)]
# model.fit(X_train, y_train, eval_metric="error", eval_set=eval_set, verbose=True)

XGBModel.fit(X,y, eval_metric="logloss")
# XGBModel.fit(X,y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.6,
#               enable_categorical=False, gamma=0.1, gpu_id=-1,
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.05, max_delta_step=0, max_depth=2,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=4, num_parallel_tree=1, predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               subsample=1, tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict_proba(X_val)

rmse = log_loss(y_val, XGBpredictions)
print('XGBoost validation Log loss = ', rmse)

#XGBoost validation Log loss =  0.6819472321905787
# Out:
# XGBoost validation Log loss =  0.6819613814931067

# %%
testX = test_data.values

y_test_pred = XGBModel.predict_proba(testX)

# y_test_pred = xgb.predict_proba(val)
y_test_pred = y_test_pred[:,1]
y_test_pred

submission_df_XG = pd.DataFrame(y_test_pred, columns=['OUTCOME'])
submission_df_XG.to_csv('submission_df_XG_100.csv', index=False)

# %%
# Out:
# array([0.43179983, 0.4477554 , 0.41881442, ..., 0.42619374, 0.38721183,
#        0.42458504], dtype=float32)
